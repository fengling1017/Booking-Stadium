# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests
from time import sleep

#登录网站
#     driver.find_element_by_xpath('//*[@id="login"]').click()
#     driver.implicitly_wait(5)
#     usename='13120702423'
#     password='******'
#     txt_username=driver.find_element_by_xpath('/html/body/div[5]/div[2]/div[4]/input')
#     txt_username.send_keys(usename)
#     txt_pw=driver.find_element_by_xpath('/html/body/div[5]/div[2]/div[5]/input')
#     txt_pw.send_keys(password)
#     sleep(8)
# #     txt_log=WebDriverWait(driver,5).until(EC.element_to_be_clickable((By.CLASS_NAME,"btn btn-login")))
#     txt_log=driver.find_element_by_xpath('/html/body/div[5]/div[2]/div[9]')
#     txt_log.click()

def booking_process(url,book_time):
    driver.get(url)
    driver.add_cookie({'name':'connect.sid','value':'s%3AtZENKdwtmqxC_NQ-YW4cUwYj0iAVflL2.0d8NtqhxMwlpe9E%2Bfn57vJn%2Fd4mc3aMWZ28s26X7rN0'})
    sleep(3)
    driver.refresh()
    driver.maximize_window()
    driver.find_element_by_xpath('//*[@class="business-order"]/div').click()
    sleep(2)
    #转换网页
    n=driver.window_handles
    driver.switch_to.window(n[1])
    sleep(2)
    driver.find_element_by_partial_link_text(book_time).click()

    for j in range(1,17):       
        for i in range(1,5):
            site=driver.find_element_by_xpath('//*[@id="booking"]/div[3]/div[1]/table/tbody/tr[{}]/td[{}]'.format(j,i))
            
            sta=site.get_attribute('status')
            if int(sta)!=0:
                print('%s号场地已经被预定'% i)
            else:
                site.click()
                sleep(3)
                driver.find_element_by_xpath('//*[@id="booking"]/div[3]/div[2]/div[2]/a').click()
                head=driver.find_element_by_class_name('headText')
                if head:
                    print('登录状态已失效，%s号场地还有，请登录预定'% i)
                sleep(2)
                scroll_bottom="window.scrollTo(0,document.body.scrollHeigth)"
                driver.execute_script(scroll_bottom)
                driver.find_element_by_xpath('//*[@class="order"]/a').click()
                sleep(2)
                driver.find_element_by_xpath('//*[@id="pay_form"]/div[1]/div[5]/div').click()
                sleep(2)
                print('%s号场地预定成功，请马上支付'% i)
                break
#         driver.quit()
        
if __name__ == '__main__':
#     profile_directory = r'--user-data-dir=C:\Users\sunf11\AppData\Local\Google\Chrome\User Data'
#     option = webdriver.ChromeOptions()
#     option.add_argument(profile_directory)
    driver=webdriver.Chrome(r'C:\chromedriver_win32\chromedriver.exe')
    url='http://www.quyundong.com/search/searchResult?random=883973048147752&search_text=%E4%BB%99%E9%9C%9E%E7%BD%91%E7%90%83%E4%B8%AD%E5%BF%83&city_id=321'
    book_time='周六'
    booking_process(url,book_time)
# 上海ID city_id=321 仙霞网球中心id ：22875-12 专硕网球中心id： 22195-12
# Out:
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定
# 1号场地已经被预定
# 2号场地已经被预定
# 3号场地已经被预定
# 4号场地已经被预定

# %%
from PIL import Image
import pytesseract
import tesserocr
im = Image.open(r'C:\Users\shic17\Desktop\123.jpg')
imgry = im.convert('L')
imgry.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-33dbc92430e8> in <module>
#       1 from PIL import Image
# ----> 2 import pytesseract
#       3 import tesserocr
#       4 im = Image.open(r'C:\Users\shic17\Desktop\123.jpg')
#       5 imgry = im.convert('L')
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
threshold = 140
table = []
for i in range(256):
    if i < threshold:
        table.append(0)
    else:
        table.append(1)
out = imgry.point(table, '1')
out.show()
# optCode = pytesseract.image_to_string(out)
# # 打印出验证码
# print(optCode)
result = tesserocr.image_to_text(out)
print(result)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-7ec9b9e6e061> in <module>
#      11 # # 打印出验证码
#      12 # print(optCode)
# ---> 13 result = tesserocr.image_to_text(out)
#      14 print(result)
#
# tesserocr.pyx in tesserocr._tesserocr.image_to_text()
#
# RuntimeError: Failed to init API, possibly an invalid tessdata path: C:\Users\shic17\Anaconda3\
